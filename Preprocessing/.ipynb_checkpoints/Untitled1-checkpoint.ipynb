# %%
import os
import string
import core_rank
from data import utils
from data import clustering
from data.meeting import meeting_lists
from collections import Counter
from nltk import PerceptronTagger
from nltk import TweetTokenizer
from dictionary_tokenizer import DictionaryTokenizer
from sklearn.model_selection import ParameterGrid
import json
import glob
import re

# %%
path_to_stopwords    = 'resources/stopwords/meeting/stopwords.' + 'en' + '.dat'
path_to_filler_words = 'resources/stopwords/meeting/filler_words.' + 'en' + '.txt'
stopwords = utils.load_stopwords(path_to_stopwords)
filler_words = utils.load_filler_words(path_to_filler_words)

# %%
def clean_utterance(utterance, filler_words):
    utt = utterance
    # replace consecutive unigrams with a single instance
    utt = re.sub('\\b(\\w+)\\s+\\1\\b', '\\1', utt)
    # same for bigrams
    utt = re.sub('(\\b.+?\\b)\\1\\b', '\\1', utt)
    # strip extra white space
    utt = re.sub(' +', ' ', utt)
    # strip leading and trailing white space
    utt = utt.strip()

    # remove filler words # highly time-consuming
    utt = ' ' + utt + ' '
    for filler_word in filler_words:
        utt = re.sub(' ' + filler_word + ' ', ' ', utt)
        utt = re.sub(' ' + filler_word + ', ', ' ', utt)
        utt = re.sub(' ' + filler_word + '. ', '.', utt)

    return utt

# %%
corpus = {}
ids = []
for text in glob.glob('data/transcript/'+'*'+'transcript.txt'):
    f = open(text, "r").read()
    id = re.sub('data/transcript\\\\', '', text)
    id = re.sub('.transcript.txt', '', id)
    raw = re.split('\. |\? |\! |\; ', f)
    utterances = []
    for i, utt in enumerate(raw):
        utt = re.sub("'Kay", 'Okay', utt)
        utt = re.sub("'kay", 'Okay', utt)
        utt = re.sub('"Okay"', 'Okay', utt)
        utt = re.sub("'cause", 'cause', utt)
        utt = re.sub("'Cause", 'cause', utt)
        utt = re.sub('"cause"', 'cause', utt)
        utt = re.sub('"\'em"', 'them', utt)
        utt = re.sub('"\'til"', 'until', utt)
        utt = re.sub('"\'s"', 's', utt)
        utt = re.sub('[.\n]', ' ', utt)

        # l. c. d. -> lcd
        # t. v. -> tv
        utt = re.sub('h. t. m. l.', 'html', utt)
        utt = re.sub(r"(\w)\_ (\w)\_ (\w)\_", r"\1\2\3", utt)
        utt = re.sub(r"(\w)\_ (\w)\_", r"\1\2", utt)
        utt = re.sub(r"(\w)\_", r"\1", utt)

        utt = clean_utterance(utt, filler_words=filler_words)
        # strip extra white space
        utt = re.sub(' +', ' ', utt)
        # strip leading and trailing white space
        utt = utt.strip()

        if utt != '' and utt != '.' and utt != ' ':
            utterances.append((i, utt))
    corpus[id] = utterances
    ids.append(id)

# %%
[5]*5
# Out:
# [5, 5, 5, 5, 5]

# %%
algorithm        = 'kmeans'
aware            = 'none'
n_comms          = 20
feature          = 'tfidf'
ngram_range      = (1, 1)
extra_features   = []
lsa              = True
lsa_n_components = 30
min_words        = 3
min_elt          = 1
w                = 3
overspanning     = True

# %%
for id in ids:
    print (id)

    utterances_indexed = corpus[id]

    # #####################################
    # ### Pre-processing for Clustering ###
    # #####################################
    utterances_processed = []
    lists_of_terms = []
    utterances_remain = []
    for utterance_indexed in utterances_indexed:
        index, utt = utterance_indexed
        utt_cleaned = utils.clean_text(
            utt,
            stopwords=stopwords,
            remove_stopwords=True,
            pos_filtering=False,
            stemming=True,
            # clustering based on lowercase form.
            lower_case=True
        )
        # remove utterances with less than min_words number of non-stopwords
        if len(utt_cleaned) >= min_words:
            utterances_processed.append((index, ' '.join(utt_cleaned)))
            lists_of_terms.append(utt_cleaned)
            utterances_remain.append(utt)
        else:
            # print "drop:", utt
            pass

    print(len(utterances_processed), 'utterances')

    # ############################
    # ### UTTERANCE CLUSTERING ###
    # ############################
    membership = clustering.cluster_utterances(
        utterances_processed,
        algorithm=algorithm,
        aware=aware,
        n_comms=len(utterances_processed)//15,
        feature=feature,
        ngram_range=ngram_range,
        extra_features=extra_features,
        lsa=lsa,
        lsa_n_components=lsa_n_components,
        twidf_window_size=w,
        meeting_id=id
    )
    
    c = dict(Counter(membership))
    comm_labels = [k for k, v in c.items() if v >= min_elt]
    
    path_to_community = 'data/community/meeting/' + 'ami' + '_' + 'v2' + '/'
    if not os.path.exists(path_to_community):
        os.makedirs(path_to_community)
    
    for i, label in enumerate(comm_labels):
        with open(path_to_community + id + '.' + str(i) + '.txt', 'w+') as txtfile:
            for my_label in [sent[0] for j, sent in enumerate(utterances_processed) if membership[j] == label]:
                to_write = [elt[1] for elt in utterances_indexed if elt[0] == my_label][0]
                # one utterance per line
                txtfile.write(to_write + '. ')
            txtfile.write('\n')
# Out:
# EN2001a
# 667 utterances

# %%
summary={}
for text in glob.glob('data/summary/'+'*'+'abssumm.txt'):
    f = open(text, "r").read()
    id = re.sub('data/summary\\\\', '', text)
    id = re.sub('.abssumm.txt', '', id)
    raw = re.split('\. |\? |\! |\; ', f)
    utterances = []
    for utt in raw:
        utt = utt.lower()
        # strip extra white space
        utt = re.sub(' +', ' ', utt)
        # strip leading and trailing white space
        utt = utt.strip()

        if utt != '' and utt != '.' and utt != ' ':
            utterances.append(utt)
    summary[id] = utterances

# %%
corpus['TS3010d']
# Out:
# [(1, 'so, now last time'),
#  (2, 'can you push the button'),
#  (3, 'one time'),
#  (4, "so i'm still the secretary"),
#  (5, 'now i ask you to presentate the prototype'),
#  (6, 'one of your you two'),
#  (7, 'yes'),
#  (8, 'the prototype'),
#  (10, 'now yes'),
#  (14, 'and the buttons'),
#  (15, 'and the joystick is for the volume and the channels'),
#  (16, 'so if joystick and lcd'),
#  (17, "what's the rr d"),
#  (18, 'very good'),
#  (19, 'so, we have so, what they say on the side is put fashion there'),
#  (20, 'yes'),
#  (21, "it's good"),
#  (22, "so, that's it"),
#  (23, "that's prototype"),
#  (24, 'now, the finance'),
#  (25, "we if it's th it if it's"),
#  (26, "so, i'm gonna look"),
#  (27, 'we have'),
#  (28, "finance is it's no, first yes"),
#  (29, 'we have to evaluate the product yet'),
#  (31, 'criteria'),
#  (32, "no, it's"),
#  (33, "it's"),
#  (34, 'what do you think'),
#  (36, 'two'),
#  (37, 'you'),
#  (38, 'me too'),
#  (39, "so it's a three"),
#  (40, "so it's a yes, it's for the younger g group"),
#  (41, "so it's half of the people"),
#  (42, "so it's four"),
#  (43, 'no'),
#  (44, 'yes'),
#  (45, "so, it's four"),
#  (47, 'give it a four'),
#  (49, 'we put the fashion in electronics'),
#  (50, 'i say a five'),
#  (51, "it's not fashion, it's new"),
#  (52, 'it must be a fashion'),
#  (53, "but it isn't"),
#  (54, 'yes'),
#  (55, "it w if it's not a fashion we can put it in it"),
#  (56, 'so, it must be a fashion'),
#  (57, "it's a five"),
#  (58, 'no'),
#  (60, 'i use my feet though'),
#  (62, 'i say three'),
#  (63, 'so, counting then is two and a half'),
#  (64, 'two'),
#  (65, 'you'),
#  (66, 'me too'),
#  (67, 'one'),
#  (68, 'next, six'),
#  (69, 'it does not get lost easily'),
#  (70, 'no, we did not'),
#  (71, "so, but can it get lost if it's such a thing"),
#  (72, "i don't"),
#  (73, 'yes'),
#  (74, 'not a normal shapes'),
#  (75, 'so no'),
#  (76, "it won't get lost"),
#  (77, 'so a one'),
#  (78, 'a one'),
#  (79, 'next'),
#  (80, 'me that was our target'),
#  (81, 'two'),
#  (83, 'right'),
#  (84, "there's a fancy look-and-feel"),
#  (86, 'i say a two'),
#  (87, "it's a bit personal"),
#  (88, "if it's fancy"),
#  (89, 'so s two is better'),
#  (90, "no, it's new"),
#  (91, 'innovation'),
#  (93, 'me too'),
#  (94, 'three'),
#  (96, 'effort is three, ten and twelve'),
#  (97, 'thirty, forty, fifty,'),
#  (98, 'twenty one'),
#  (99, "so, it's two and three nine two and one third"),
#  (101, 'nah'),
#  (103, "so, it's good"),
#  (107, 'back to my'),
#  (108, 'next'),
#  (109, 'so, now we have a product'),
#  (110, 'very happy'),
#  (111, 'but is it cheap enough'),
#  (112, "so if i'll have a look"),
#  (113, 'we have a battery'),
#  (114, 'one battery'),
#  (115, 'one battery'),
#  (116, 'electronics'),
#  (117, 'advanced chip'),
#  (118, "it's the most advanced"),
#  (119, 'chip-on-print'),
#  (120, 'we have that one'),
#  (121, 'we have the simple, regular and advanced'),
#  (122, 'we have the adva advanced'),
#  (123, 'Okay, so uncurved or flat'),
#  (124, 'nope'),
#  (125, 'single curved or double curved'),
#  (126, 'we have double curved'),
#  (127, 'so then we have plastic, wood, rubber'),
#  (128, 'we have half rubber, half plastic'),
#  (129, 'no titanium'),
#  (130, 'special colour'),
#  (131, 'yes, yellow'),
#  (132, 'interface, push-button'),
#  (133, 'scroll-wheel, integrated scroll-wheel push-button, or lcd display'),
#  (134, 'so, we have the lcd we have two scroll-wheels'),
#  (135, 'or one'),
#  (136, "and it's not really a s it's this one"),
#  (137, 'now, button supplement'),
#  (138, 'special colour'),
#  (139, "we already that's the from the for the buttons"),
#  (140, 'the buttons are regular colour'),
#  (141, 'so, then then then no'),
#  (142, "it's too expensive"),
#  (143, 'so, we have to change something'),
#  (144, 'fifteen euros'),
#  (145, "when we lose one scroll-wheel, it's"),
#  (146, "we can't lose the battery"),
#  (147, "we can't lose the advanced chip"),
#  (148, "we can't lose the double curve"),
#  (149, 'we have rubber, special colour'),
#  (150, "no, we no, it's"),
#  (151, 'then we lose two euros'),
#  (152, 'then we have thirteen euros'),
#  (153, 'half a euro too much'),
#  (154, 'exactly the special colours'),
#  (155, "so that's one euro"),
#  (156, "so, i don't think that's good"),
#  (157, 'we have to keep the lcd'),
#  (158, 'if yes'),
#  (159, "then it's only thirteen euros"),
#  (160, 'so'),
#  (162, 'then you have or you have to cut this off'),
#  (163, "then it's not good anymore"),
#  (164, 'so,'),
#  (166, "i'll have a look"),
#  (167, 'we yellow rubber'),
#  (168, 'normal'),
#  (169, 'one minute,'),
#  (170, 'is it maximum'),
#  (171, "it's normal colour"),
#  (172, "but if you lose the joystick, it's still an advanced chip"),
#  (173, "or it's then a regular"),
#  (174, 'so, the advanced is for the lcd and the regular for the joystick'),
#  (175, 'and what if we lose the lcd'),
#  (176, 'regular chip'),
#  (177, 'but is it a good design'),
#  (178, 'yes'),
#  (179, "then it's"),
#  (180, 'so no joystick'),
#  (181, 'no, but we then we get push-buttons from half a euro'),
#  (182, 'yes, yes'),
#  (183, 'no joystick'),
#  (184, 'push-buttons'),
#  (185, 'no special colour'),
#  (186, 'twelve and a half euros'),
#  (187, "then it's"),
#  (188, 'so, we have to change that a little bit'),
#  (189, 'and you cannot use the red and green button'),
#  (190, 'because if you give them a s colour, you have to pay point two euros'),
#  (191, 'yes'),
#  (192, 'yes'),
#  (193, "so now we have to change that, but that's"),
#  (194, 'rubber'),
#  (195, "what's the normal colour"),
#  (196, "so and where's"),
#  (198, "so, now it's"),
#  (199, 'it is'),
#  (200, 'but then it will be just that ones'),
#  (201, "now it's very good"),
#  (202, 'now, project eva evaluation'),
#  (203, 'what do you think of it'),
#  (204, 'about the project'),
#  (206, 'and you'),
#  (209, 'what do i have to say'),
#  (210, 'it was good'),
#  (211, 'not too many discussions'),
#  (212, "so, it's good for the speed"),
#  (213, "so, we're ready"),
#  (214, 'good price'),
#  (215, 'evaluation ready'),
#  (216, 'ready'),
#  (217, "that's it this, you mean"),
#  (218, 'yes, this is it'),
#  (219, "it's it's yellow"),
#  (220, 'and this is rubber'),
#  (221, 'and this too'),
#  (222, 'the sides'),
#  (223, 'and the rest is hard plastic'),
#  (224, 'and we had some we had a new idea that this can can be turned inside'),
#  (225, 'and then it covers the these buttons until here'),
#  (226,
#   'and then you can still use the power button and the mute and the joystick'),
#  (227, 'so, you can still operate all the things'),
#  (228, "because you don't always use the menu"),
#  (229, 'and then it can break'),
#  (230, 'big buttons'),
#  (231, 'and everything is blue, except the power button'),
#  (232, 'and the mute'),
#  (233, 'of and the mute and the other button'),
#  (235, 'channel higher channel button'),
#  (236, 'yes'),
#  (237, "yes, that's very obvious"),
#  (239, "rr's the l the company logo"),
#  (240, 'yes'),
#  (241, 'yes'),
#  (242, "that's about here"),
#  (244, 'three'),
#  (245, 'four'),
#  (246, "but it's"),
#  (247, 'it still has l large buttons and not m many buttons'),
#  (248, 'so the colours are for young people, but older'),
#  (250, 'maybe'),
#  (251, 'yes'),
#  (252, 'two'),
#  (253, 'then make it th three'),
#  (254, 'yes, a one'),
#  (255, 'i like it'),
#  (256, 'one'),
#  (257, 'yes'),
#  (258, 'but'),
#  (260, 'yes, a one'),
#  (262, 'three'),
#  (263, 'yes'),
#  (265, 'yes'),
#  (270, 'all the same'),
#  (271, 'recognisable'),
#  (272, 'like what'),
#  (275, 'the same'),
#  (276,
#   'i espe i especially liked the means, the smartboard and it it brings up new ideas when you work with with it'),
#  (279, "no i don't care"),
#  (281, 'big'),
#  (282, 'yes'),
#  (283, 'up is channel up'),
#  (284, 'down is channel down'),
#  (285, 'to the right is volume up'),
#  (286, 'to the left is volume down'),
#  (287, 'the rr'),
#  (288, "i'll get it"),
#  (289, 'the scroll-button is something also new'),
#  (290, 'what not anoth not a lot of remote controls have'),
#  (291, "technologically i'll give it an seven"),
#  (292, 'si six'),
#  (293, 'six'),
#  (294, 'true or false'),
#  (295, "i'll give it a t a two"),
#  (297, 'five'),
#  (299, 'maybe version three point o has other colours'),
#  (300, 'four'),
#  (301,
#   'me too a two, because only the battery is not techin technologically high standard'),
#  (302, 'but the rest of it is'),
#  (303, 'so, a two'),
#  (304, 'it will be fashion'),
#  (305, 'Okay'),
#  (306, 'three is'),
#  (307, "we'll outside"),
#  (308, 'i give it a one'),
#  (309, 'say two'),
#  (310, 'two'),
#  (311, 'one'),
#  (312, 'just a small thing'),
#  (314, 'yellow'),
#  (315, 'looks like a pistol'),
#  (316, "it won't get between the pillows on the couch"),
#  (317, 'o one'),
#  (319, 'me too'),
#  (320, 'two'),
#  (323, 'i gave this a one because of the rubber'),
#  (324, 'it feels soft'),
#  (325, 'it looks like a l b a bit like a joystick'),
#  (326, "it's"),
#  (327, 'f very fancy trendy'),
#  (328, 'two is'),
#  (330, 'i go for two because the shapes are still round'),
#  (331, 'the latest trends are soft things, like i said in my presentation'),
#  (332, 'but the colours are basic, like yellow, red, blue'),
#  (333, 'something what also younger people want'),
#  (334, "it's also a trend, so i'll give it a two"),
#  (335, 'two'),
#  (337, 'cheapest there is'),
#  (338, 'expensive'),
#  (339, "it's the most advanced"),
#  (340, 'advanced'),
#  (341, 'yellow'),
#  (342, 'one'),
#  (343, 'joystick thing'),
#  (344, "we're not gonna make it"),
#  (346, 'wh what are the costs'),
#  (347, 'fifteen'),
#  (348, 'a special colour'),
#  (349, "i don't think it's a very special colour"),
#  (350, 'yellow'),
#  (351, 'is it a special colour'),
#  (352, 'what'),
#  (354, 'and what if we use only one just only plastic or only rubber'),
#  (355, 'one euro discount'),
#  (356,
#   'if we change the joyst the joystick thing into a button up, button down, button right, button left'),
#  (357, "and then we'll lose fifty cent in what"),
#  (358, 'uh-uh'),
#  (359, 'no'),
#  (360,
#   "and if you say it's just a r normal colour it's a normal colour, wh no one will see it"),
#  (361,
#   'normal colour, and the joystick away, and put the button up, button down, right, left'),
#  (362, "and it's twelve euros,"),
#  (363, 'no'),
#  (364, 'no, no'),
#  (365, 'wait'),
#  (370, 'if we lose the lcd, then we have an regular chip and no lcd'),
#  (372, "then you'll have to m see the menu on the television"),
#  (373, "and you don't have the lcd"),
#  (374, 'so, the tvs has to have to be up-to-date'),
#  (378, 'no knew that'),
#  (379, "then it's twelve euro fifty, then it's"),
#  (380, 'so, all the buttons has to have to be the same colour'),
#  (381, 'but then the print on it will g change it'),
#  (382, 'make it for everybody to see what button it is'),
#  (383, 'l how you call it'),
#  (384, 'recognisable,'),
#  (387, "that's clear"),
#  (388, 'and the joystick away'),
#  (389, 'and its buttons'),
#  (391, 'about the process'),
#  (392, 'went good'),
#  (393, 'the creativity was good enough'),
#  (394, 'we have a gun instead of a remote control'),
#  (395, 'leadership'),
#  (396, 'you were the project manager, and had the final vote'),
#  (397, 'so that was clear'),
#  (398, 'team-work'),
#  (399, 'everybody has something to say about it'),
#  (400, 'and no, o only the drawing was very difficult'),
#  (401, 'but, nah'),
#  (402, 'new ideas found'),
#  (403, 'nope'),
#  (404, 'no'),
#  (406, 'beer'),
#  (408, 'then this is it'),
#  (409, 'yes'),
#  (411, "that's on the rub rubber part"),
#  (413, 'alright'),
#  (414, 'do we change the do we change the order'),
#  (415, 'or are we going to ev evaluate it first'),
#  (417, "that's that can be none"),
#  (418, 'we gonna do the evaluation now, together'),
#  (419, 'but i have a introduction how it works'),
#  (420, 'so, it will come up'),
#  (421, 'uh-oh'),
#  (424,
#   'we i have thinked a few evaluation criterias, based on our marketing strategy, on the latest trends, on user preferences'),
#  (425, 'we have a seven point scale from true, as'),
#  (426, 'to false, seven'),
#  (427, 'and on base of each c criteria, we need to give a rating'),
#  (428, 'we can it look like this'),
#  (429, 'but we gonna do it here, they said'),
#  (430, 'so, you hope found out how to do it with a word document'),
#  (434, 'we have the word document you so we open up that blank here'),
#  (435, 'think what this just an example'),
#  (436, 'so, this not very important'),
#  (437, 'but if get a number in here'),
#  (439, "we can't do that"),
#  (440,
#   'so you have to think of it as the remote control is techno technologically innovative'),
#  (441, 'and then we have to agree on the rating together'),
#  (442, 'and in the end, we will c count an average of all rating'),
#  (443, 'the first on each item'),
#  (444,
#   "it's technologically using, it's not it doesn't contain many new features"),
#  (445, 'only the lcd'),
#  (446, 'so, it i will give it a.a four'),
#  (448, 'so now you see it its statement'),
#  (449, 'and you true or false'),
#  (450, 'and true is one'),
#  (451, 'so,'),
#  (453, 'Okay'),
#  (454, "it's a one"),
#  (455, 'the first item'),
#  (456, 'so, the second item'),
#  (457, 'this product is for all sorts of customers'),
#  (458,
#   "it's a statement which i disagree with, because we really aim at young market and the way it looked c in yellow, it's not really aimed for all customers"),
#  (459, "it doesn't look like that"),
#  (460, "that's a six"),
#  (461, 'four'),
#  (464, "that's the motto of our company"),
#  (465, 'do we do this with this product'),
#  (466, 'i'),
#  (467, "if we do this, as it's c it's really orientates on the design"),
#  (468, 'so i would give it a two'),
#  (469, 'two'),
#  (472, "yes, i'll think of that too"),
#  (473, 'agree'),
#  (474, 'a three'),
#  (476, 'the next element is the product looks good'),
#  (477, "personally, i do not prefer a remote control that's fully in yellow"),
#  (478, 'so, i would give this a five'),
#  (479, 'we have to do our two or three'),
#  (480, 'two'),
#  (482, 'so, we gonna do the next part'),
#  (484, 'the next statement'),
#  (485, 'it has not too much buttons'),
#  (486, 'i have said is not because a low number is better'),
#  (487, 'and in the end we calculate an average'),
#  (488, "so, that's why it's a negative in it"),
#  (489, 'this one of our aims not have too much buttons'),
#  (490, 'so, did we do that'),
#  (491,
#   'if we go to this fashion, i we still have.a lot of buttons for the numbers'),
#  (492, 'but you can go for that'),
#  (493, "and that way, you don't have a lot of buttons over"),
#  (494, 'so, i would give this a two'),
#  (495, 'one'),
#  (496, 'but where is the'),
#  (497, 'so did we implement the sound'),
#  (499, "it won't"),
#  (500, 'one'),
#  (501, 'we aimed for the younger market'),
#  (502, 'did we achieve that'),
#  (503, 'with the way it looks and it is designed, i will give it a two'),
#  (505, 'yes'),
#  (506, 'that was one of the most important things that trendwatch said'),
#  (507, "i didn't say it in my presentation"),
#  (508, 'but does it have that'),
#  (509, 'i would say yes'),
#  (510, "so let's also give this a two"),
#  (511, 't'),
#  (513, 'two'),
#  (514,
#   'and then the last one i could think of, it goes with the latest trends'),
#  (515,
#   "if we looked at the latest trends for the younger people, and they ate fruit and vegetables, it has a a colour, compared to food but we didn't we did not paint any fruit and vegetable on it for something like that"),
#  (516, 'so, i would did not give this a one or two'),
#  (517, "i we'll go for a three"),
#  (518, 'yes'),
#  (519, 'a three'),
#  (521, 'so come back to the presentation now'),
#  (522,
#   'so, we find yourself there, and now we have to calculate an average rating'),
#  (523, 'so, we will do that'),
#  (524, 'yes'),
#  (525, 'by nine'),
#  (528, 'two'),
#  (529, 'come on'),
#  (530, "so that's a pretty low rating,"),
#  (531, 'so, according to our own evaluation we did a good job'),
#  (533, 'nah'),
#  (534, 'how am i doing'),
#  (535, 'yes'),
#  (536, 'and i closed your slide-show'),
#  (537, 'which one was the last for you'),
#  (538, 'dreaming'),
#  (539, 'next'),
#  (540, 'finance'),
#  (542, 'one'),
#  (543, 'we would have n for a remote control'),
#  (544, "i've for a remote control, it is"),
#  (545, 'if we would have normal buttons instead of the joystick'),
#  (546, 'for up down left right'),
#  (547, "the advanced chip was for the lcd wasn't it"),
#  (548,
#   'if if we have the n no buttons if we have not a joystick but buttons, we would have we have thirteen euros'),
#  (549, 'and then we move the colour'),
#  (550, 'what will that be'),
#  (552, 'still, he waited at the no'),
#  (553, 'project'),
#  (554,
#   'you have to compare it to if you would have a normal normal project without laptops and without these devices'),
#  (555,
#   'the laptops if you have them out front of you, you sometimes looking at that instead of the presentation'),
#  (556, 'the draw-board, you can draw things'),
#  (557, 'but it not really going very convenient'),
#  (558,
#   'maybe it will be easier if you have a smaller monitor and you would also see there'),
#  (559, 'and with a normal mouse'),
#  (560, 'and the project'),
#  (561, 'i agree on what was said mainly'),
#  (562, 'but you always have that some people are talking more than others'),
#  (563,
#   'and maybe is then the task of the project manager to also ask more to the people less talking'),
#  (564, 'to tell their opinion')]

# %%
summary['TS3010d']
# Out:
# ['the industrial designer and user interface designer presented their prototype design, made of yellow rubber and hard plastic, with large, mostly blue buttons, a joystick and lcd screen',
#  'led by the marketing expert, the group evaluated the prototype on a scale of one to seven, based on a set of evaluation criteria',
#  'the overall rating was two',
#  'the project manager calculated the production costs, which were too high at fifteen euros',
#  'the group discussed how to make the design cheaper, and decided to keep the lcd screen, but to remove the special colour and replace the joystick with regular push-buttons',
#  'finally the project manager led an evaluation of the project process before closing the meeting',
#  'overall, the group were satisfied with the creativity, teamwork and available equipment, although the marketing expert thought the smartboard and laptops were sometimes distracting and not that helpful']

# %%
for id in summary.keys():
    print (id)

    utterances_indexed = corpus[id]
   
    summ = summary[id]

    # #####################################
    # ### Pre-processing for Clustering ###
    # #####################################
    utterances_processed = []
    lists_of_terms = []
    utterances_remain = []
    for utterance_indexed in utterances_indexed:
        index, utt = utterance_indexed
        utt_cleaned = utils.clean_text(
            utt,
            stopwords=stopwords,
            remove_stopwords=True,
            pos_filtering=False,
            stemming=True,
            # clustering based on lowercase form.
            lower_case=True
        )
        # remove utterances with less than min_words number of non-stopwords
        if len(utt_cleaned) >= min_words:
            utterances_processed.append((index, ' '.join(utt_cleaned)))
            lists_of_terms.append(utt_cleaned)
            utterances_remain.append(utt)
        else:
            # print "drop:", utt
            pass

    print(len(utterances_processed), 'utterances')

    # ############################
    # ### UTTERANCE CLUSTERING ###
    # ############################
    membership = clustering.cluster_utterances(
        utterances_processed,
        algorithm=algorithm,
        aware=aware,
        n_comms=len(utterances_processed)//5,
        feature=feature,
        ngram_range=ngram_range,
        extra_features=extra_features,
        lsa=lsa,
        lsa_n_components=lsa_n_components,
        twidf_window_size=w,
        meeting_id=id,
        sent_num=10
    )
    
    c = dict(Counter(membership))
    comm_labels = [k for k, v in c.items() if v >= min_elt]
    
    path_to_community = 'data/story5/'
    if not os.path.exists(path_to_community):
        os.makedirs(path_to_community)
    
    for i, label in enumerate(comm_labels):
        with open(path_to_community + id + '.' + str(i) + '.story', 'w+') as story_file:
            for my_label in [sent[0] for j, sent in enumerate(utterances_processed) if membership[j] == label]:
                to_write = [elt[1] for elt in utterances_indexed if elt[0] == my_label][0]
                # one utterance per line
                story_file.write(to_write + '. ')
            for sent in summ:
                story_file.write('\n\n@highlight\n\n{}'.format(sent))
            story_file.write('\n')
# Out:
# ES2002a
# 94 utterances
# ES2002b
# 204 utterances
# ES2002c
# 214 utterances
# ES2002d
# 198 utterances
# ES2003a
# 64 utterances
# ES2003b
# 166 utterances
# ES2003c
# 196 utterances
# ES2003d
# 202 utterances
# ES2004a
# 80 utterances
# ES2004b
# 179 utterances
# ES2004c
# 192 utterances
# ES2004d
# 189 utterances
# ES2005a
# 23 utterances
# ES2005b
# 180 utterances
# ES2005c
# 197 utterances
# ES2005d
# 107 utterances
# ES2006a
# 77 utterances
# ES2006b
# 168 utterances
# ES2006c
# 187 utterances
# ES2006d
# 183 utterances
# ES2007a
# 85 utterances
# ES2007b
# 134 utterances
# ES2007c
# 192 utterances
# ES2007d
# 96 utterances
# ES2008a
# 76 utterances
# ES2008b
# 190 utterances
# ES2008c
# 183 utterances
# ES2008d
# 234 utterances
# ES2009a
# 115 utterances
# ES2009b
# 121 utterances
# ES2009c
# 181 utterances
# ES2009d
# 183 utterances
# ES2010a
# 47 utterances
# ES2010b
# 162 utterances
# ES2010c
# 178 utterances
# ES2010d
# 97 utterances
# ES2011a
# 71 utterances
# ES2011b
# 111 utterances
# ES2011c
# 140 utterances
# ES2011d
# 132 utterances
# ES2012a
# 60 utterances
# ES2012b
# 159 utterances
# ES2012c
# 161 utterances
# ES2012d
# 57 utterances
# ES2013a
# 54 utterances
# ES2013b
# 150 utterances
# ES2013c
# 194 utterances
# ES2013d
# 148 utterances
# ES2014a
# 76 utterances
# ES2014b
# 190 utterances
# ES2014c
# 218 utterances
# ES2014d
# 256 utterances
# ES2015a
# 81 utterances
# ES2015b
# 258 utterances
# ES2015c
# 229 utterances
# ES2015d
# 166 utterances
# ES2016a
# 98 utterances
# ES2016b
# 179 utterances
# ES2016c
# 199 utterances
# ES2016d
# 119 utterances
# IB4003
# 204 utterances
# IB4005
# 221 utterances
# IB4010
# 288 utterances
# IB4011
# 221 utterances
# IS1000a
# 84 utterances
# IS1000b
# 138 utterances
# IS1000c
# 134 utterances
# IS1000d
# 212 utterances
# IS1001a
# 55 utterances
# IS1001b
# 139 utterances
# IS1001c
# 116 utterances
# IS1001d
# 38 utterances
# IS1002b
# 233 utterances
# IS1002c
# 186 utterances
# IS1002d
# 108 utterances
# IS1003a
# 38 utterances
# IS1003b
# 139 utterances
# IS1003c
# 165 utterances
# IS1003d
# 218 utterances
# IS1004a
# 48 utterances
# IS1004b
# 183 utterances
# IS1004c
# 184 utterances
# IS1004d
# 138 utterances
# IS1005a
# 48 utterances
# IS1005b
# 157 utterances
# IS1005c
# 155 utterances
# IS1006a
# 56 utterances
# IS1006b
# 148 utterances
# IS1006c
# 119 utterances
# IS1006d
# 132 utterances
# IS1007a
# 60 utterances
# IS1007b
# 101 utterances
# IS1007c
# 160 utterances
# IS1007d
# 161 utterances
# IS1008a
# 60 utterances
# IS1008b
# 142 utterances
# IS1008c
# 119 utterances
# IS1008d
# 127 utterances
# IS1009a
# 66 utterances
# IS1009b
# 142 utterances
# IS1009c
# 148 utterances
# IS1009d
# 167 utterances
# TS3003a
# 88 utterances
# TS3003b
# 181 utterances
# TS3003c
# 172 utterances
# TS3003d
# 153 utterances
# TS3004a
# 86 utterances
# TS3004b
# 209 utterances
# TS3004c
# 194 utterances
# TS3004d
# 185 utterances
# TS3005a
# 92 utterances
# TS3005b
# 251 utterances
# TS3005c
# 198 utterances
# TS3005d
# 266 utterances
# TS3006a
# 75 utterances
# TS3006b
# 208 utterances
# TS3006c
# 225 utterances
# TS3006d
# 233 utterances
# TS3007a
# 102 utterances
# TS3007b
# 184 utterances
# TS3007c
# 240 utterances
# TS3007d
# 260 utterances
# TS3008a
# 88 utterances
# TS3008b
# 215 utterances
# TS3008c
# 218 utterances
# TS3008d
# 264 utterances
# TS3009a
# 128 utterances
# TS3009b
# 225 utterances
# TS3009c
# 216 utterances
# TS3009d
# 195 utterances
# TS3010a
# 31 utterances
# TS3010b
# 121 utterances
# TS3010c
# 124 utterances
# TS3010d
# 79 utterances
# TS3011a
# 116 utterances
# TS3011b
# 208 utterances
# TS3011c
# 204 utterances
# TS3011d
# 133 utterances
# TS3012a
# 79 utterances
# TS3012b
# 260 utterances
# TS3012c
# 259 utterances
# TS3012d
# 202 utterances

# %%
train_files, valid_files, test_files = [], [], []

# %%
import random
from random import shuffle
dataset = list(summary.keys())
size = len(dataset)
random.seed(2020)
shuffle(dataset)
for i, f in enumerate(dataset):
    if i < size * 0.1:
        test_files.append(f)
    elif i < size * 0.2:
        valid_files.append(f)
    else:
        train_files.append(f)

# %%
train_files, valid_files, test_files
# Out:
# (['IS1006d',
#   'ES2008c',
#   'ES2003d',
#   'ES2012c',
#   'ES2003a',
#   'IS1003c',
#   'ES2011a',
#   'ES2008b',
#   'ES2010c',
#   'IS1000d',
#   'TS3006a',
#   'ES2002b',
#   'TS3006b',
#   'IS1002c',
#   'IB4011',
#   'IS1006b',
#   'ES2009a',
#   'ES2012d',
#   'ES2007b',
#   'IS1004c',
#   'ES2005c',
#   'ES2014c',
#   'TS3011b',
#   'TS3004c',
#   'TS3009b',
#   'ES2013b',
#   'IS1003b',
#   'ES2009b',
#   'ES2010d',
#   'TS3005c',
#   'TS3011c',
#   'ES2007c',
#   'IS1009b',
#   'ES2004a',
#   'IS1001c',
#   'IS1005b',
#   'IS1006a',
#   'IS1007c',
#   'TS3004a',
#   'IS1007b',
#   'TS3005a',
#   'ES2005a',
#   'TS3004d',
#   'TS3009a',
#   'TS3008a',
#   'TS3008b',
#   'ES2014b',
#   'ES2015c',
#   'ES2006a',
#   'IS1005a',
#   'ES2011b',
#   'IS1002b',
#   'TS3003d',
#   'TS3011d',
#   'TS3012c',
#   'IS1000c',
#   'TS3003b',
#   'TS3012b',
#   'IS1000b',
#   'ES2009d',
#   'ES2016c',
#   'IS1004b',
#   'IS1009a',
#   'IS1000a',
#   'ES2011d',
#   'ES2009c',
#   'ES2016d',
#   'TS3009c',
#   'IS1001b',
#   'IS1004d',
#   'ES2002d',
#   'ES2006d',
#   'IS1008c',
#   'ES2010b',
#   'IS1003d',
#   'ES2004d',
#   'IS1006c',
#   'TS3010d',
#   'ES2005d',
#   'ES2008d',
#   'TS3012d',
#   'TS3010a',
#   'ES2003c',
#   'ES2016a',
#   'ES2003b',
#   'TS3003a',
#   'IB4003',
#   'IS1008b',
#   'IS1001a',
#   'IS1004a',
#   'TS3005b',
#   'TS3007b',
#   'IB4010',
#   'ES2007a',
#   'IS1005c',
#   'IS1007a',
#   'ES2005b',
#   'ES2016b',
#   'TS3007c',
#   'ES2011c',
#   'ES2015a',
#   'TS3003c',
#   'ES2015b',
#   'IB4005',
#   'TS3006d',
#   'ES2007d',
#   'ES2012a',
#   'TS3004b',
#   'IS1008a',
#   'TS3007d',
#   'TS3005d',
#   'TS3007a',
#   'ES2013a'],
#  ['IS1003a',
#   'ES2004c',
#   'IS1002d',
#   'TS3012a',
#   'TS3010c',
#   'IS1009d',
#   'ES2002a',
#   'TS3009d',
#   'ES2014a',
#   'IS1008d',
#   'ES2006b',
#   'ES2013c',
#   'IS1009c',
#   'TS3006c'],
#  ['TS3008c',
#   'ES2008a',
#   'ES2015d',
#   'ES2010a',
#   'ES2012b',
#   'IS1007d',
#   'TS3008d',
#   'TS3011a',
#   'ES2004b',
#   'ES2013d',
#   'TS3010b',
#   'ES2002c',
#   'ES2006c',
#   'ES2014d',
#   'IS1001d'])

# %%
print(len(test_files))
# Out:
# 15

# %%
print(6//5)
# Out:
# 1
